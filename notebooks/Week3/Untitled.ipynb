# %%
# !pip install streamlit
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------  8.9/9.1 MB 50.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 43.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/795.4 kB ? eta -:--:--
#    ---------------------------------------- 795.4/795.4 kB 33.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------------------------ --------- 5.2/6.9 MB 63.9 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/6.9 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 13.7 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/12 [watchdog]
#    ----------------------------------------  0/12 [watchdog]
# ...

# %%
import streamlit
